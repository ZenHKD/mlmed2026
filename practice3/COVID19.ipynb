# %%
# %run train1.py
# Out:
# Using device: cuda
# ...
# Phase 1: Lung Segmentation Training
# ...
# Loaded 21715 samples from Train split
#   COVID-19: 7658
#   Non-COVID: 7208
#   Normal: 6849
# Loaded 5417 samples from Val split
#   COVID-19: 1903
#   Non-COVID: 1802
#   Normal: 1712
#
# Training samples: 21715
# Validation samples: 5417
# Image size: (256, 256), Batch size: 8
# Number of epochs: 50, Learning rate: 0.0001
# --------------------------------------------------------------------------------
#
# Phase 1 Layer Freezing:
#   [FROZEN] Infection decoder blocks
#   [FROZEN] Infection cross-attention
#   [FROZEN] Infection head
#   [TRAINABLE] Encoder, PPM, Lung decoder, Lung head, Classification head
#
# Total parameters: 44,089,967
# Trainable parameters: 36,693,582
# Frozen parameters: 7,396,385
#
# Starting training...
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# %run test1.py
# Out:
# Using device: cuda
# ...
# Phase 1: Lung Segmentation Testing
# ...
# Loaded 6788 samples from Test split
#
# Test samples: 6788
# --------------------------------------------------------------------------------
# Loaded model from epoch 49 (val_dice: 0.9746)
#
# Evaluating on test set...
# Evaluating: 100%|██████████| 425/425 [00:57<00:00,  7.42it/s]
# ...
# TEST RESULTS
# ...
#
# [Segmentation Metrics]
#   Dice Score: 0.9727
#   IoU Score:  0.9477
#
# [Classification Metrics]
#   Accuracy:  0.9399
#   Precision: 0.9399 (macro)
#   Recall:    0.9383 (macro)
#   F1 Score:  0.9388 (macro)
#
# [Per-Class Metrics]
# ------------------------------------------------------------------------------------------
# Class        Count    Dice     IoU      Acc      Prec     Recall   F1
# ------------------------------------------------------------------------------------------
# Normal       2140     0.9844   0.9695   0.8981   0.9463   0.8981   0.9216
# ...

# %%
# %run train2.py
# Out:
# Using device: cuda
# ...
# Phase 2: Infection Segmentation Training
# ...
# Loaded 3728 samples from Train
#   Normal: 932
#   Non-COVID: 932
#   COVID-19: 1864
# Loaded 932 samples from Val
#   Normal: 233
#   Non-COVID: 233
#   COVID-19: 466
#
# Training samples: 3728
# Validation samples: 932
# Image size: (256, 256), Batch size: 8
# Number of epochs: 30, Learning rate: 0.0001
# --------------------------------------------------------------------------------
#
# Loaded Phase 1 model from epoch 49
# Phase 1 val_dice: 0.9746, val_acc: 0.9289274506184235
#
# Phase 2: All layers unfrozen for fine-tuning
# Total parameters: 44,089,967
# Trainable parameters: 44,089,967
#
# Starting training...
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 001  |  lr 1.00e-05  |  train: L 0.9054 I 0.0565 acc 0.6754  |  val: L 0.9619 I 0.0788 acc 0.7629  |  *** Best ***
# ...

# %%
# %run test2.py
# Out:
# Using device: cuda
# ...
# Phase 2: Infection Segmentation Testing
# ...
# Loaded 1166 samples from Test
#
# Test samples: 1166
# --------------------------------------------------------------------------------
# Loaded model from epoch 10
#   val_lung_dice: 0.9684417736835969
#   val_inf_dice: 0.7556412352407411
#   val_acc: 0.9216738197424893
#
# Evaluating on test set...
# Evaluating: 100%|██████████| 73/73 [00:10<00:00,  7.17it/s]
# ...
# TEST RESULTS
# ...
#
# [Segmentation Metrics]
#   Lung Dice:      0.9645
#   Lung IoU:       0.9330
#   Infection Dice: 0.7407
#   Infection IoU:  0.6312
#
# [Classification Metrics]
#   Accuracy:  0.9220
#   Precision: 0.9032 (macro)
#   Recall:    0.9028 (macro)
#   F1 Score:  0.9029 (macro)
#
# [Per-Class Metrics]
# ----------------------------------------------------------------------------------------------------
# Class        Count    L.Dice     I.Dice     Acc      Prec     Recall   F1
# ...
